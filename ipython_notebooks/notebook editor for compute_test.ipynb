# %%
# -*- coding: utf-8 -*-
import dataiku
from dataiku import spark as dkuspark
from pyspark import SparkContext
from pyspark.sql import SQLContext

# %%
sc = SparkContext.getOrCreate()
sqlContext = SQLContext(sc)
# Out:
# /home/dataiku/dataiku-dss-10.0.7/spark-standalone-home/python/pyspark/sql/context.py:79: DeprecationWarning: Deprecated in 3.0.0. Use SparkSession.builder.getOrCreate() instead.
#   DeprecationWarning)

# %%
# Read recipe inputs
SARINAPREFIXTEST_COPY = dataiku.Dataset("SARINAPREFIXTEST_COPY")
SARINAPREFIXTEST_COPY_df = dkuspark.get_dataframe(sqlContext, SARINAPREFIXTEST_COPY)

# %%
# Compute recipe outputs from inputs
# TODO: Replace this part by your actual code that computes the output, as a SparkSQL dataframe
test_df = SARINAPREFIXTEST_COPY_df # For this sample code, simply copy input to output

# Write recipe outputs
test = dataiku.Dataset("test")
dkuspark.write_with_schema(test, test_df)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-9-589aaefe96c8> in <module>()
#       5 # Write recipe outputs
#       6 test = dataiku.Dataset("test")
# ----> 7 dkuspark.write_with_schema(test, test_df)
#
# /home/dataiku/dataiku-dss-10.0.7/python/dataiku/spark/__init__.py in write_with_schema(dataset, dataframe, delete_first)
#     192
#     193     write_schema_from_dataframe(dataset, dataframe)
# --> 194     write_dataframe(dataset, dataframe, delete_first)
#     195
#     196
#
# /home/dataiku/dataiku-dss-10.0.7/python/dataiku/spark/__init__.py in write_dataframe(dataset, dataframe, delete_first)
#     182
#     183     dsc = __dataikuSparkContext(dataframe._sc._jvm)
# --> 184     dsc.savePyDataFrame(dataset.full_name, dataframe._jdf, dataset.writePartition, delete_first and "OVERWRITE" or "APPEND", False)
#     185
#     186
#
# /home/dataiku/dataiku-dss-10.0.7/spark-standalone-home/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
# -> 1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#    1307         for temp_arg in temp_args:
#
# /home/dataiku/dataiku-dss-10.0.7/spark-standalone-home/python/pyspark/sql/utils.py in deco(*a, **kw)
#     109     def deco(*a, **kw):
#     110         try:
# --> 111             return f(*a, **kw)
#     112         except py4j.protocol.Py4JJavaError as e:
#     113             converted = convert_exception(e.java_exception)
#
# /home/dataiku/dataiku-dss-10.0.7/spark-standalone-home/python/lib/py4j-0.10.9-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     326                 raise Py4JJavaError(
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#     330                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling o46.savePyDataFrame.
# : com.dataiku.common.server.APIError$APIErrorException: !390190!
# 	at com.dataiku.dip.util.HTTPClientUtils.handleJSONResp(HTTPClientUtils.java:222)
# 	at com.dataiku.common.rpc.InternalAPIClient.handleJSONResp(InternalAPIClient.java:866)
# 	at com.dataiku.common.rpc.InternalAPIClient.postFormToJSON(InternalAPIClient.java:462)
# 	at com.dataiku.dip.spark.StdDataikuSparkContext$.$anonfun$executeCommand$2(StdDataikuSparkContext.scala:1116)
# 	at com.dataiku.dip.utils.package$.tryWith(package.scala:28)
# 	at com.dataiku.dip.spark.StdDataikuSparkContext$.executeCommand(StdDataikuSparkContext.scala:1115)
# 	at com.dataiku.dip.spark.SnowflakeFastpathSupport$.saveSnowflakeDataset(SnowflakeFastpathSupport.scala:135)
# 	at com.dataiku.dip.spark.StdDataikuSparkContext.internalSave(StdDataikuSparkContext.scala:764)
# 	at com.dataiku.dss.spark.DataikuSparkContext.save(DataikuSparkContext.scala:83)
# 	at com.dataiku.dss.spark.DataikuSparkContext.save$(DataikuSparkContext.scala:75)
# 	at com.dataiku.dip.spark.StdDataikuSparkContext.save(StdDataikuSparkContext.scala:54)
# 	at com.dataiku.dip.spark.StdDataikuSparkContext.savePyDataFrame(StdDataikuSparkContext.scala:535)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:750)

# %%
SARINAPREFIXTEST_COPY.get_dataframe()
# Out:
# Empty DataFrame
# Columns: [CUSTOMER_ID, ORDER_DATE_YEAR_DISTINCT, ORDER_DATE_MONTH_DISTINCT, ORDER_DAY_OF_WEEK_DISTINCT, PAGES_VISITED_AVG, TOTAL_SUM, GENDER, AGE_FIRST_ORDER, USER_AGENT_BRAND, USER_AGENT_OS, USER_AGENT_OSVERSION, USER_AGENT_OSFLAVOR, IP_ADDRESS_GEOPOINT, IP_ADDRESS_CITY, IP_ADDRESS_COUNTRY, CAMPAIGN, DATASET, COUNT]
# Index: []

# %%
SARINAPREFIXTEST_COPY_df.count()
# Out:
# 10724

# %%
SARINAPREFIXTEST_COPY_df.collect()
# Out:
# [Row(CUSTOMER_ID='000018', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('3'), PAGES_VISITED_AVG=12.0, TOTAL_SUM=55.5, GENDER='F', AGE_FIRST_ORDER=59.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(21.0362 52.2394)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Poland', CAMPAIGN=False, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='000071', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('3'), PAGES_VISITED_AVG=12.666666666666664, TOTAL_SUM=91.0, GENDER='F', AGE_FIRST_ORDER=48.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(139.69 35.69)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Japan', CAMPAIGN=True, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='000440', ORDER_DATE_YEAR_DISTINCT=Decimal('4'), ORDER_DATE_MONTH_DISTINCT=Decimal('4'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('4'), PAGES_VISITED_AVG=14.2, TOTAL_SUM=313.0, GENDER='M', AGE_FIRST_ORDER=44.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-2 8)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Ghana', CAMPAIGN=True, DATASET='training', COUNT=Decimal('5')),
#  Row(CUSTOMER_ID='000452', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=15.0, TOTAL_SUM=83.0, GENDER='M', AGE_FIRST_ORDER=62.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(139.69 35.69)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Japan', CAMPAIGN=False, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='000652', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=10.0, TOTAL_SUM=43.0, GENDER='M', AGE_FIRST_ORDER=20.0, USER_AGENT_BRAND='Firefox', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='000747', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=14.5, TOTAL_SUM=39.0, GENDER='M', AGE_FIRST_ORDER=49.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='000759', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=13.666666666666664, TOTAL_SUM=292.0, GENDER='M', AGE_FIRST_ORDER=25.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Linux', USER_AGENT_OSVERSION='10.11.6', USER_AGENT_OSFLAVOR='Ubuntu', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='South Korea', CAMPAIGN=False, DATASET='training', COUNT=Decimal('6')),
#  Row(CUSTOMER_ID='000879', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=12.666666666666664, TOTAL_SUM=152.0, GENDER='F', AGE_FIRST_ORDER=57.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(103.8558 1.2931)', IP_ADDRESS_CITY='Singapore', IP_ADDRESS_COUNTRY='Singapore', CAMPAIGN=False, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='000887', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=13.5, TOTAL_SUM=46.0, GENDER='F', AGE_FIRST_ORDER=27.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Linux', USER_AGENT_OSVERSION=None, USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(6.4833 46.3667)', IP_ADDRESS_CITY='Thonon-les-Bains', IP_ADDRESS_COUNTRY='France', CAMPAIGN=True, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='001226', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=12.333333333333336, TOTAL_SUM=123.0, GENDER='F', AGE_FIRST_ORDER=60.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(113.7266 34.7725)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='China', CAMPAIGN=False, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='001247', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('4'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('3'), PAGES_VISITED_AVG=12.0, TOTAL_SUM=247.0, GENDER='F', AGE_FIRST_ORDER=59.0, USER_AGENT_BRAND='Safari', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-6.2489 53.3331)', IP_ADDRESS_CITY='Dublin', IP_ADDRESS_COUNTRY='Ireland', CAMPAIGN=True, DATASET='training', COUNT=Decimal('4')),
#  Row(CUSTOMER_ID='001275', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('4'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('4'), PAGES_VISITED_AVG=10.0, TOTAL_SUM=337.5, GENDER='F', AGE_FIRST_ORDER=65.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('4')),
#  Row(CUSTOMER_ID='001411', ORDER_DATE_YEAR_DISTINCT=Decimal('4'), ORDER_DATE_MONTH_DISTINCT=Decimal('6'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('4'), PAGES_VISITED_AVG=8.833333333333334, TOTAL_SUM=305.0, GENDER=None, AGE_FIRST_ORDER=69.0, USER_AGENT_BRAND='Firefox', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(138.6333 -34.8333)', IP_ADDRESS_CITY='Ingle Farm', IP_ADDRESS_COUNTRY='Australia', CAMPAIGN=True, DATASET='training', COUNT=Decimal('6')),
#  Row(CUSTOMER_ID='001492', ORDER_DATE_YEAR_DISTINCT=Decimal('4'), ORDER_DATE_MONTH_DISTINCT=Decimal('5'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('4'), PAGES_VISITED_AVG=12.0, TOTAL_SUM=220.5, GENDER='F', AGE_FIRST_ORDER=23.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(139.69 35.69)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Japan', CAMPAIGN=True, DATASET='training', COUNT=Decimal('7')),
#  Row(CUSTOMER_ID='001571', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('3'), PAGES_VISITED_AVG=13.333333333333336, TOTAL_SUM=66.0, GENDER='M', AGE_FIRST_ORDER=42.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(121.5318 25.0478)', IP_ADDRESS_CITY='Taipei', IP_ADDRESS_COUNTRY='Taiwan', CAMPAIGN=False, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='001682', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=7.0, TOTAL_SUM=20.0, GENDER='M', AGE_FIRST_ORDER=69.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(77.2 28.6)', IP_ADDRESS_CITY='New Delhi', IP_ADDRESS_COUNTRY='India', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='001771', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=16.0, TOTAL_SUM=20.0, GENDER='M', AGE_FIRST_ORDER=15.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(103.8399 36.057)', IP_ADDRESS_CITY='Lanzhou', IP_ADDRESS_COUNTRY='China', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='001onj', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=8.0, TOTAL_SUM=18.0, GENDER='F', AGE_FIRST_ORDER=72.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.11.6', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT=None, IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY=None, CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='002158', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=14.0, TOTAL_SUM=23.0, GENDER='M', AGE_FIRST_ORDER=68.0, USER_AGENT_BRAND='Firefox', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(143.2104 -33.494)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Australia', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='002241', ORDER_DATE_YEAR_DISTINCT=Decimal('5'), ORDER_DATE_MONTH_DISTINCT=Decimal('8'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('6'), PAGES_VISITED_AVG=7.0, TOTAL_SUM=1051.0, GENDER=None, AGE_FIRST_ORDER=63.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-87.9845 43.2364)', IP_ADDRESS_CITY='Mequon', IP_ADDRESS_COUNTRY='United States', CAMPAIGN=True, DATASET='training', COUNT=Decimal('10')),
#  Row(CUSTOMER_ID='002402', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=9.0, TOTAL_SUM=20.0, GENDER=None, AGE_FIRST_ORDER=35.0, USER_AGENT_BRAND='Safari', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='002431', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=11.5, TOTAL_SUM=46.0, GENDER='M', AGE_FIRST_ORDER=45.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(101.9435 2.7486)', IP_ADDRESS_CITY='Seremban', IP_ADDRESS_COUNTRY='Malaysia', CAMPAIGN=False, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='002453', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('3'), PAGES_VISITED_AVG=12.333333333333336, TOTAL_SUM=93.0, GENDER='F', AGE_FIRST_ORDER=45.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.10.5', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(139.69 35.69)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Japan', CAMPAIGN=True, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='002555', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=15.0, TOTAL_SUM=19.0, GENDER='M', AGE_FIRST_ORDER=None, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.11.6', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(121 23.5)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Taiwan', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='002938', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=11.0, TOTAL_SUM=23.0, GENDER='M', AGE_FIRST_ORDER=24.0, USER_AGENT_BRAND='Safari', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-66 8)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Venezuela', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='003194', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=7.0, TOTAL_SUM=19.0, GENDER='F', AGE_FIRST_ORDER=76.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-77.6845 43.1685)', IP_ADDRESS_CITY='Rochester', IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='003314', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=15.0, TOTAL_SUM=23.0, GENDER='M', AGE_FIRST_ORDER=31.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='003374', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=11.0, TOTAL_SUM=36.0, GENDER='F', AGE_FIRST_ORDER=24.0, USER_AGENT_BRAND='Safari', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(11.6989 47.8819)', IP_ADDRESS_CITY='Holzkirchen', IP_ADDRESS_COUNTRY='Germany', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='003696', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('3'), PAGES_VISITED_AVG=9.333333333333334, TOTAL_SUM=93.0, GENDER='M', AGE_FIRST_ORDER=50.0, USER_AGENT_BRAND='Safari', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='003742', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=15.0, TOTAL_SUM=20.0, GENDER='M', AGE_FIRST_ORDER=63.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='004074', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=9.0, TOTAL_SUM=23.0, GENDER='M', AGE_FIRST_ORDER=None, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-71.5213 42.9403)', IP_ADDRESS_CITY='Bedford', IP_ADDRESS_COUNTRY='United States', CAMPAIGN=True, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='004139', ORDER_DATE_YEAR_DISTINCT=Decimal('4'), ORDER_DATE_MONTH_DISTINCT=Decimal('8'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('6'), PAGES_VISITED_AVG=9.111111111111109, TOTAL_SUM=455.0, GENDER='F', AGE_FIRST_ORDER=40.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-58.3817 -34.6033)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Argentina', CAMPAIGN=True, DATASET='training', COUNT=Decimal('9')),
#  Row(CUSTOMER_ID='004524', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=16.0, TOTAL_SUM=19.0, GENDER='M', AGE_FIRST_ORDER=18.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.11.6', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(116.3883 39.9289)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='China', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='004753', ORDER_DATE_YEAR_DISTINCT=Decimal('5'), ORDER_DATE_MONTH_DISTINCT=Decimal('5'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('4'), PAGES_VISITED_AVG=11.8, TOTAL_SUM=238.0, GENDER='M', AGE_FIRST_ORDER=51.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(143.2104 -33.494)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Australia', CAMPAIGN=False, DATASET='training', COUNT=Decimal('5')),
#  Row(CUSTOMER_ID='004802', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=19.0, TOTAL_SUM=19.0, GENDER='M', AGE_FIRST_ORDER=47.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(113.7266 34.7725)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='China', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='004901', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=11.0, TOTAL_SUM=40.0, GENDER='F', AGE_FIRST_ORDER=70.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='004915', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=10.333333333333334, TOTAL_SUM=96.0, GENDER='M', AGE_FIRST_ORDER=60.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.11.6', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(113.7266 34.7725)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='China', CAMPAIGN=False, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='004977', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=13.0, TOTAL_SUM=23.0, GENDER='M', AGE_FIRST_ORDER=57.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-96.3528 42.4671)', IP_ADDRESS_CITY='Sioux City', IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='005100', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=12.0, TOTAL_SUM=17.5, GENDER=None, AGE_FIRST_ORDER=72.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(113.7266 34.7725)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='China', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='005357', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=12.5, TOTAL_SUM=59.0, GENDER='M', AGE_FIRST_ORDER=40.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(121 23.5)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Taiwan', CAMPAIGN=False, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='005415', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=9.5, TOTAL_SUM=72.0, GENDER='F', AGE_FIRST_ORDER=69.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-0.085 51.6515)', IP_ADDRESS_CITY='Enfield Town', IP_ADDRESS_COUNTRY='United Kingdom', CAMPAIGN=True, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='005604', ORDER_DATE_YEAR_DISTINCT=Decimal('4'), ORDER_DATE_MONTH_DISTINCT=Decimal('4'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('4'), PAGES_VISITED_AVG=9.666666666666666, TOTAL_SUM=308.0, GENDER='F', AGE_FIRST_ORDER=71.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-1.245 50.678)', IP_ADDRESS_CITY='Newport', IP_ADDRESS_COUNTRY='United Kingdom', CAMPAIGN=True, DATASET='training', COUNT=Decimal('6')),
#  Row(CUSTOMER_ID='005639', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=11.0, TOTAL_SUM=17.5, GENDER='F', AGE_FIRST_ORDER=None, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=True, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='005737', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=12.0, TOTAL_SUM=23.0, GENDER='F', AGE_FIRST_ORDER=16.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.11.6', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='005779', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=11.5, TOTAL_SUM=43.0, GENDER='M', AGE_FIRST_ORDER=45.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(-121.3287 38.6284)', IP_ADDRESS_CITY='Carmichael', IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='005971', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=7.5, TOTAL_SUM=64.0, GENDER='M', AGE_FIRST_ORDER=70.0, USER_AGENT_BRAND='Safari', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=True, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='006022', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=13.0, TOTAL_SUM=23.0, GENDER='F', AGE_FIRST_ORDER=39.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(174.7635 -36.8485)', IP_ADDRESS_CITY='Auckland', IP_ADDRESS_COUNTRY='New Zealand', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='006283', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=14.0, TOTAL_SUM=23.0, GENDER='M', AGE_FIRST_ORDER=24.0, USER_AGENT_BRAND='Firefox', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(51.4231 35.6961)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Iran', CAMPAIGN=True, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='006476', ORDER_DATE_YEAR_DISTINCT=Decimal('4'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('3'), PAGES_VISITED_AVG=11.0, TOTAL_SUM=167.5, GENDER='F', AGE_FIRST_ORDER=53.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(-93.3811 45.0632)', IP_ADDRESS_CITY='Minneapolis', IP_ADDRESS_COUNTRY='United States', CAMPAIGN=True, DATASET='training', COUNT=Decimal('4')),
#  Row(CUSTOMER_ID='006523', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('4'), PAGES_VISITED_AVG=10.75, TOTAL_SUM=82.5, GENDER='M', AGE_FIRST_ORDER=32.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT=None, IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY=None, CAMPAIGN=True, DATASET='training', COUNT=Decimal('4')),
#  Row(CUSTOMER_ID='006555', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=12.333333333333336, TOTAL_SUM=141.5, GENDER='M', AGE_FIRST_ORDER=42.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(-78.1566 38.7078)', IP_ADDRESS_CITY='Washington', IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='006711', ORDER_DATE_YEAR_DISTINCT=Decimal('4'), ORDER_DATE_MONTH_DISTINCT=Decimal('5'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('4'), PAGES_VISITED_AVG=11.6, TOTAL_SUM=219.0, GENDER='F', AGE_FIRST_ORDER=59.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Linux', USER_AGENT_OSVERSION=None, USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=True, DATASET='training', COUNT=Decimal('5')),
#  Row(CUSTOMER_ID='006743', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('3'), PAGES_VISITED_AVG=10.666666666666666, TOTAL_SUM=100.5, GENDER='F', AGE_FIRST_ORDER=64.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(28.0583 -26.2309)', IP_ADDRESS_CITY='Johannesburg', IP_ADDRESS_COUNTRY='South Africa', CAMPAIGN=False, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='006846', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=9.0, TOTAL_SUM=134.5, GENDER='F', AGE_FIRST_ORDER=45.0, USER_AGENT_BRAND='Safari', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(30 15)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Sudan', CAMPAIGN=False, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='006850', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('3'), PAGES_VISITED_AVG=8.666666666666666, TOTAL_SUM=1179.0, GENDER='F', AGE_FIRST_ORDER=68.0, USER_AGENT_BRAND='Firefox', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-43.2192 -22.8305)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Brazil', CAMPAIGN=False, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='007135', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=8.0, TOTAL_SUM=18.0, GENDER='F', AGE_FIRST_ORDER=65.0, USER_AGENT_BRAND='Firefox', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-1.5 52.9333)', IP_ADDRESS_CITY='Derby', IP_ADDRESS_COUNTRY='United Kingdom', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='007217', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=9.5, TOTAL_SUM=123.0, GENDER='M', AGE_FIRST_ORDER=61.0, USER_AGENT_BRAND='Firefox', USER_AGENT_OS='Linux', USER_AGENT_OSVERSION=None, USER_AGENT_OSFLAVOR='Ubuntu', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='007356', ORDER_DATE_YEAR_DISTINCT=Decimal('5'), ORDER_DATE_MONTH_DISTINCT=Decimal('5'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('5'), PAGES_VISITED_AVG=11.2, TOTAL_SUM=270.0, GENDER='F', AGE_FIRST_ORDER=61.0, USER_AGENT_BRAND='Safari', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(8.4311 49.3208)', IP_ADDRESS_CITY='Speyer', IP_ADDRESS_COUNTRY='Germany', CAMPAIGN=False, DATASET='training', COUNT=Decimal('5')),
#  Row(CUSTOMER_ID='007494', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=11.5, TOTAL_SUM=86.0, GENDER='F', AGE_FIRST_ORDER=43.0, USER_AGENT_BRAND='Firefox', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='007537', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=13.0, TOTAL_SUM=41.0, GENDER='M', AGE_FIRST_ORDER=66.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-58.3817 -34.6033)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Argentina', CAMPAIGN=False, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='007585', ORDER_DATE_YEAR_DISTINCT=Decimal('4'), ORDER_DATE_MONTH_DISTINCT=Decimal('5'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('3'), PAGES_VISITED_AVG=6.4, TOTAL_SUM=264.0, GENDER='F', AGE_FIRST_ORDER=60.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(117.1571 34.1805)', IP_ADDRESS_CITY='Xuzhou', IP_ADDRESS_COUNTRY='China', CAMPAIGN=True, DATASET='training', COUNT=Decimal('5')),
#  Row(CUSTOMER_ID='007660', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=12.0, TOTAL_SUM=43.0, GENDER='M', AGE_FIRST_ORDER=33.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(120.9686 24.8036)', IP_ADDRESS_CITY='Hsinchu', IP_ADDRESS_COUNTRY='Taiwan', CAMPAIGN=False, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='007762', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=14.5, TOTAL_SUM=62.0, GENDER='F', AGE_FIRST_ORDER=64.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='007921', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('3'), PAGES_VISITED_AVG=9.333333333333334, TOTAL_SUM=116.0, GENDER='M', AGE_FIRST_ORDER=None, USER_AGENT_BRAND='Firefox', USER_AGENT_OS='Linux', USER_AGENT_OSVERSION=None, USER_AGENT_OSFLAVOR='Ubuntu', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=True, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='007955', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=13.0, TOTAL_SUM=24.0, GENDER='F', AGE_FIRST_ORDER=71.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='008006', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=5.0, TOTAL_SUM=17.5, GENDER='F', AGE_FIRST_ORDER=33.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(-58.3817 -34.6033)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Argentina', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='008025', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=18.0, TOTAL_SUM=20.0, GENDER='M', AGE_FIRST_ORDER=73.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.11.6', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(9.9412 57.0355)', IP_ADDRESS_CITY='Aalborg', IP_ADDRESS_COUNTRY='Denmark', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='008070', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=12.5, TOTAL_SUM=35.5, GENDER='F', AGE_FIRST_ORDER=47.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='008194', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=16.0, TOTAL_SUM=23.0, GENDER='M', AGE_FIRST_ORDER=17.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(12.1097 43.1479)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Italy', CAMPAIGN=True, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='008605', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('4'), PAGES_VISITED_AVG=10.0, TOTAL_SUM=155.0, GENDER='F', AGE_FIRST_ORDER=65.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(11.9106 55.008)', IP_ADDRESS_CITY='Vordingborg', IP_ADDRESS_COUNTRY='Denmark', CAMPAIGN=True, DATASET='training', COUNT=Decimal('4')),
#  Row(CUSTOMER_ID='008680', ORDER_DATE_YEAR_DISTINCT=Decimal('4'), ORDER_DATE_MONTH_DISTINCT=Decimal('4'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('4'), PAGES_VISITED_AVG=14.25, TOTAL_SUM=184.0, GENDER='F', AGE_FIRST_ORDER=47.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(139.69 35.69)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Japan', CAMPAIGN=False, DATASET='training', COUNT=Decimal('4')),
#  Row(CUSTOMER_ID='008885', ORDER_DATE_YEAR_DISTINCT=Decimal('4'), ORDER_DATE_MONTH_DISTINCT=Decimal('5'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('5'), PAGES_VISITED_AVG=10.0, TOTAL_SUM=195.0, GENDER=None, AGE_FIRST_ORDER=48.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(-0.1224 51.4964)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United Kingdom', CAMPAIGN=True, DATASET='training', COUNT=Decimal('5')),
#  Row(CUSTOMER_ID='009245', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=17.0, TOTAL_SUM=71.5, GENDER='F', AGE_FIRST_ORDER=56.0, USER_AGENT_BRAND='Firefox', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(2.3387 48.8582)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='France', CAMPAIGN=True, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='009625', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('3'), PAGES_VISITED_AVG=8.333333333333334, TOTAL_SUM=81.0, GENDER='M', AGE_FIRST_ORDER=63.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 8.1', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='009910', ORDER_DATE_YEAR_DISTINCT=Decimal('5'), ORDER_DATE_MONTH_DISTINCT=Decimal('5'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('4'), PAGES_VISITED_AVG=7.8, TOTAL_SUM=285.5, GENDER='F', AGE_FIRST_ORDER=62.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=True, DATASET='training', COUNT=Decimal('5')),
#  Row(CUSTOMER_ID='009918', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=15.0, TOTAL_SUM=43.0, GENDER='M', AGE_FIRST_ORDER=43.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 8.1', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='00bx65', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=11.0, TOTAL_SUM=65.0, GENDER=None, AGE_FIRST_ORDER=63.0, USER_AGENT_BRAND='Safari', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-79.3716 43.6319)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Canada', CAMPAIGN=True, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='00q4am', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('5'), PAGES_VISITED_AVG=12.0, TOTAL_SUM=266.0, GENDER=None, AGE_FIRST_ORDER=36.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(113.7266 34.7725)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='China', CAMPAIGN=True, DATASET='training', COUNT=Decimal('6')),
#  Row(CUSTOMER_ID='00tguu', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=10.0, TOTAL_SUM=20.0, GENDER=None, AGE_FIRST_ORDER=63.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(121.3997 31.0456)', IP_ADDRESS_CITY='Shanghai', IP_ADDRESS_COUNTRY='China', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='010116', ORDER_DATE_YEAR_DISTINCT=Decimal('4'), ORDER_DATE_MONTH_DISTINCT=Decimal('5'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('4'), PAGES_VISITED_AVG=12.2, TOTAL_SUM=153.0, GENDER='F', AGE_FIRST_ORDER=None, USER_AGENT_BRAND='Safari', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(126.8219 37.3236)', IP_ADDRESS_CITY='Ansan-si', IP_ADDRESS_COUNTRY='South Korea', CAMPAIGN=True, DATASET='training', COUNT=Decimal('5')),
#  Row(CUSTOMER_ID='010308', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=17.0, TOTAL_SUM=18.0, GENDER='F', AGE_FIRST_ORDER=27.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-70.6667 -33.45)', IP_ADDRESS_CITY='Santiago', IP_ADDRESS_COUNTRY='Chile', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='010311', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=15.0, TOTAL_SUM=35.0, GENDER=None, AGE_FIRST_ORDER=31.0, USER_AGENT_BRAND='Firefox', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=True, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='010379', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=17.0, TOTAL_SUM=19.0, GENDER='M', AGE_FIRST_ORDER=48.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(9.491 51.2993)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Germany', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='010681', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=15.0, TOTAL_SUM=20.0, GENDER='F', AGE_FIRST_ORDER=20.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-0.1224 51.4964)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United Kingdom', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='010684', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=15.0, TOTAL_SUM=46.0, GENDER='M', AGE_FIRST_ORDER=17.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Linux', USER_AGENT_OSVERSION=None, USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(153.0215 -27.4732)', IP_ADDRESS_CITY='Brisbane', IP_ADDRESS_COUNTRY='Australia', CAMPAIGN=False, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='010797', ORDER_DATE_YEAR_DISTINCT=Decimal('4'), ORDER_DATE_MONTH_DISTINCT=Decimal('5'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('4'), PAGES_VISITED_AVG=8.4, TOTAL_SUM=475.5, GENDER='M', AGE_FIRST_ORDER=49.0, USER_AGENT_BRAND='Firefox', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-8.611 41.1496)', IP_ADDRESS_CITY='Porto', IP_ADDRESS_COUNTRY='Portugal', CAMPAIGN=True, DATASET='training', COUNT=Decimal('5')),
#  Row(CUSTOMER_ID='010839', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=20.0, TOTAL_SUM=19.0, GENDER='F', AGE_FIRST_ORDER=26.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(2.3387 48.8582)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='France', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='010952', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=13.0, TOTAL_SUM=23.0, GENDER='F', AGE_FIRST_ORDER=21.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(120.5954 31.3041)', IP_ADDRESS_CITY='Suzhou', IP_ADDRESS_COUNTRY='China', CAMPAIGN=True, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='011015', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=10.0, TOTAL_SUM=20.0, GENDER='M', AGE_FIRST_ORDER=61.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(21.1391 52.2181)', IP_ADDRESS_CITY='Warsaw', IP_ADDRESS_COUNTRY='Poland', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='011177', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('3'), PAGES_VISITED_AVG=11.666666666666664, TOTAL_SUM=212.0, GENDER='M', AGE_FIRST_ORDER=31.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(126.9741 37.5112)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='South Korea', CAMPAIGN=True, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='011274', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=13.0, TOTAL_SUM=40.5, GENDER='F', AGE_FIRST_ORDER=28.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(113.5325 34.6836)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='China', CAMPAIGN=False, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='011363', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=7.0, TOTAL_SUM=46.0, GENDER='M', AGE_FIRST_ORDER=55.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(12.3301 51.2187)', IP_ADDRESS_CITY='Zwenkau', IP_ADDRESS_COUNTRY='Germany', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='011387', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('3'), PAGES_VISITED_AVG=11.333333333333336, TOTAL_SUM=109.0, GENDER='M', AGE_FIRST_ORDER=29.0, USER_AGENT_BRAND='Safari', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(43.9797 49.3033)', IP_ADDRESS_CITY='Ilovlya', IP_ADDRESS_COUNTRY='Russia', CAMPAIGN=True, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='011439', ORDER_DATE_YEAR_DISTINCT=Decimal('4'), ORDER_DATE_MONTH_DISTINCT=Decimal('4'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('3'), PAGES_VISITED_AVG=8.75, TOTAL_SUM=261.0, GENDER='M', AGE_FIRST_ORDER=None, USER_AGENT_BRAND='Firefox', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(-87.6517 41.8483)', IP_ADDRESS_CITY='Chicago', IP_ADDRESS_COUNTRY='United States', CAMPAIGN=True, DATASET='training', COUNT=Decimal('4')),
#  Row(CUSTOMER_ID='011451', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=13.333333333333336, TOTAL_SUM=195.0, GENDER='M', AGE_FIRST_ORDER=None, USER_AGENT_BRAND='Firefox', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(4.35 50.85)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Belgium', CAMPAIGN=True, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='011753', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=9.0, TOTAL_SUM=20.0, GENDER='M', AGE_FIRST_ORDER=23.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
# ...
#  Row(CUSTOMER_ID='117388', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('3'), PAGES_VISITED_AVG=14.0, TOTAL_SUM=989.0, GENDER='M', AGE_FIRST_ORDER=53.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(125.57 -8.57)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Democratic Republic of Timor-Leste', CAMPAIGN=False, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='117437', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=11.0, TOTAL_SUM=18.0, GENDER='F', AGE_FIRST_ORDER=59.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='117657', ORDER_DATE_YEAR_DISTINCT=Decimal('4'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=10.0, TOTAL_SUM=164.0, GENDER='M', AGE_FIRST_ORDER=65.0, USER_AGENT_BRAND='Edge', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-43.2192 -22.8305)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Brazil', CAMPAIGN=False, DATASET='training', COUNT=Decimal('4')),
#  Row(CUSTOMER_ID='117891', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=13.5, TOTAL_SUM=35.5, GENDER='F', AGE_FIRST_ORDER=22.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 8.1', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(45 40)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Armenia', CAMPAIGN=True, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='118045', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=13.0, TOTAL_SUM=23.0, GENDER='F', AGE_FIRST_ORDER=32.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(8.6823 50.1153)', IP_ADDRESS_CITY='Frankfurt am Main', IP_ADDRESS_COUNTRY='Germany', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='118081', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('4'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('3'), PAGES_VISITED_AVG=9.75, TOTAL_SUM=125.0, GENDER='F', AGE_FIRST_ORDER=67.0, USER_AGENT_BRAND='Safari', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(31.223 30.0355)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Egypt', CAMPAIGN=False, DATASET='training', COUNT=Decimal('4')),
#  Row(CUSTOMER_ID='118190', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=14.0, TOTAL_SUM=23.0, GENDER='M', AGE_FIRST_ORDER=17.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(46.7152 24.6537)', IP_ADDRESS_CITY='Riyadh', IP_ADDRESS_COUNTRY='Saudi Arabia', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='118448', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('3'), PAGES_VISITED_AVG=9.0, TOTAL_SUM=59.5, GENDER=None, AGE_FIRST_ORDER=64.0, USER_AGENT_BRAND='Firefox', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='118653', ORDER_DATE_YEAR_DISTINCT=Decimal('4'), ORDER_DATE_MONTH_DISTINCT=Decimal('4'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('4'), PAGES_VISITED_AVG=9.6, TOTAL_SUM=169.0, GENDER='F', AGE_FIRST_ORDER=39.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-88.8424 43.8454)', IP_ADDRESS_CITY='Ripon', IP_ADDRESS_COUNTRY='United States', CAMPAIGN=True, DATASET='training', COUNT=Decimal('5')),
#  Row(CUSTOMER_ID='118657', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=11.0, TOTAL_SUM=23.0, GENDER='M', AGE_FIRST_ORDER=21.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='118785', ORDER_DATE_YEAR_DISTINCT=Decimal('4'), ORDER_DATE_MONTH_DISTINCT=Decimal('6'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('4'), PAGES_VISITED_AVG=10.833333333333336, TOTAL_SUM=255.0, GENDER='M', AGE_FIRST_ORDER=60.0, USER_AGENT_BRAND='Safari', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=True, DATASET='training', COUNT=Decimal('6')),
#  Row(CUSTOMER_ID='118827', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=8.0, TOTAL_SUM=19.0, GENDER='M', AGE_FIRST_ORDER=45.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(104.0667 30.6667)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='China', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='118833', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('2'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=14.5, TOTAL_SUM=44.0, GENDER='M', AGE_FIRST_ORDER=56.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-8.1967 52.8619)', IP_ADDRESS_CITY='Nenagh', IP_ADDRESS_COUNTRY='Ireland', CAMPAIGN=False, DATASET='training', COUNT=Decimal('2')),
#  Row(CUSTOMER_ID='118950', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=12.0, TOTAL_SUM=90.5, GENDER=None, AGE_FIRST_ORDER=47.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-70.3883 43.5254)', IP_ADDRESS_CITY='Old Orchard Beach', IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='119036', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('4'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('4'), PAGES_VISITED_AVG=14.25, TOTAL_SUM=164.0, GENDER='M', AGE_FIRST_ORDER=48.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(28.0583 -26.2309)', IP_ADDRESS_CITY='Johannesburg', IP_ADDRESS_COUNTRY='South Africa', CAMPAIGN=False, DATASET='training', COUNT=Decimal('4')),
#  Row(CUSTOMER_ID='119096', ORDER_DATE_YEAR_DISTINCT=Decimal('4'), ORDER_DATE_MONTH_DISTINCT=Decimal('5'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('3'), PAGES_VISITED_AVG=7.8, TOTAL_SUM=216.0, GENDER='F', AGE_FIRST_ORDER=52.0, USER_AGENT_BRAND='Firefox', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('5')),
#  Row(CUSTOMER_ID='119218', ORDER_DATE_YEAR_DISTINCT=Decimal('2'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=9.666666666666666, TOTAL_SUM=67.0, GENDER='M', AGE_FIRST_ORDER=39.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 8.1', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(139.69 35.69)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Japan', CAMPAIGN=True, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='119434', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('5'), PAGES_VISITED_AVG=8.714285714285714, TOTAL_SUM=241.0, GENDER='M', AGE_FIRST_ORDER=59.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(17.1067 48.1482)', IP_ADDRESS_CITY='Bratislava', IP_ADDRESS_COUNTRY='Slovakia', CAMPAIGN=True, DATASET='training', COUNT=Decimal('7')),
#  Row(CUSTOMER_ID='119549', ORDER_DATE_YEAR_DISTINCT=Decimal('5'), ORDER_DATE_MONTH_DISTINCT=Decimal('4'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('5'), PAGES_VISITED_AVG=8.333333333333334, TOTAL_SUM=523.0, GENDER='M', AGE_FIRST_ORDER=53.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(77 20)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='India', CAMPAIGN=True, DATASET='training', COUNT=Decimal('6')),
#  Row(CUSTOMER_ID='119910', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=14.0, TOTAL_SUM=18.0, GENDER='F', AGE_FIRST_ORDER=71.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(9.491 51.2993)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Germany', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='119924', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=10.0, TOTAL_SUM=23.0, GENDER='M', AGE_FIRST_ORDER=23.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(139.69 35.69)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Japan', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='11rfwd', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=11.0, TOTAL_SUM=46.0, GENDER='F', AGE_FIRST_ORDER=None, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(4.8995 52.3824)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Netherlands', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='11s0vx', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=15.0, TOTAL_SUM=35.0, GENDER='F', AGE_FIRST_ORDER=60.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.10.5', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(-41.9902 -18.7907)', IP_ADDRESS_CITY='Governador Valadares', IP_ADDRESS_COUNTRY='Brazil', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='120164', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=14.0, TOTAL_SUM=17.5, GENDER='F', AGE_FIRST_ORDER=63.0, USER_AGENT_BRAND='Safari', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.11.6', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(120.3694 36.066)', IP_ADDRESS_CITY='Qingdao', IP_ADDRESS_COUNTRY='China', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='120424', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=15.0, TOTAL_SUM=24.0, GENDER='F', AGE_FIRST_ORDER=55.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(7.2661 43.7031)', IP_ADDRESS_CITY='Nice', IP_ADDRESS_COUNTRY='France', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='120893', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=11.0, TOTAL_SUM=19.0, GENDER='M', AGE_FIRST_ORDER=41.0, USER_AGENT_BRAND='IE', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='120957', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=18.0, TOTAL_SUM=19.0, GENDER='M', AGE_FIRST_ORDER=None, USER_AGENT_BRAND='Firefox', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(-105.2771 40.0375)', IP_ADDRESS_CITY='Boulder', IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='121039', ORDER_DATE_YEAR_DISTINCT=Decimal('4'), ORDER_DATE_MONTH_DISTINCT=Decimal('4'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('4'), PAGES_VISITED_AVG=8.2, TOTAL_SUM=176.0, GENDER='F', AGE_FIRST_ORDER=57.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(2.1146 48.8612)', IP_ADDRESS_CITY='Louveciennes', IP_ADDRESS_COUNTRY='France', CAMPAIGN=True, DATASET='training', COUNT=Decimal('5')),
#  Row(CUSTOMER_ID='121147', ORDER_DATE_YEAR_DISTINCT=Decimal('3'), ORDER_DATE_MONTH_DISTINCT=Decimal('3'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('2'), PAGES_VISITED_AVG=12.333333333333336, TOTAL_SUM=143.0, GENDER='F', AGE_FIRST_ORDER=None, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='MacOS X', USER_AGENT_OSVERSION='10.12.3', USER_AGENT_OSFLAVOR=None, IP_ADDRESS_GEOPOINT='POINT(12.1097 43.1479)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='Italy', CAMPAIGN=False, DATASET='training', COUNT=Decimal('3')),
#  Row(CUSTOMER_ID='121182', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=9.0, TOTAL_SUM=19.0, GENDER='M', AGE_FIRST_ORDER=70.0, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=True, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='121262', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=12.0, TOTAL_SUM=23.0, GENDER='M', AGE_FIRST_ORDER=44.0, USER_AGENT_BRAND='Firefox', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 10', USER_AGENT_OSFLAVOR='64 bits', IP_ADDRESS_GEOPOINT='POINT(-97.822 37.751)', IP_ADDRESS_CITY=None, IP_ADDRESS_COUNTRY='United States', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  Row(CUSTOMER_ID='121555', ORDER_DATE_YEAR_DISTINCT=Decimal('1'), ORDER_DATE_MONTH_DISTINCT=Decimal('1'), ORDER_DAY_OF_WEEK_DISTINCT=Decimal('1'), PAGES_VISITED_AVG=10.0, TOTAL_SUM=19.0, GENDER='M', AGE_FIRST_ORDER=None, USER_AGENT_BRAND='Chrome', USER_AGENT_OS='Windows', USER_AGENT_OSVERSION='Windows 7', USER_AGENT_OSFLAVOR='32 bits', IP_ADDRESS_GEOPOINT='POINT(2.4937 48.8164)', IP_ADDRESS_CITY='Champigny-sur-Marne', IP_ADDRESS_COUNTRY='France', CAMPAIGN=False, DATASET='training', COUNT=Decimal('1')),
#  ...]
